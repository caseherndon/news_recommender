# %%
import pandas as pd

df = pd.read_json(r"C:\Users\caseh\Documents\MIND\data\raw\train.jsonl", lines=True, nrows=5)
print(df)
# Out:
#    id                                              query  \
# 0   1  ['Wheel Of Fortune' Guest Delivers Hilarious, ...
# 1   2  ['Habitual stowaway' arrested again at O'Hare,...
# 2   3  [Couple Didn't Know Why Car Was Running Strang...
# 3   4  [Former Deadliest Catch Star Jerod Sechrist Ar...
# 4   5  [The Difference Between Green and Orange Antif...
#
#                                             positive  \
# 0  [Charles Rogers, former Michigan State footbal...
# 1  [No. 1 milk company declares bankruptcy amid d...
# 2  [I moved from the US to the UK. Here are the 8...
# 3  [Broadway Star Laurel Griggs Suffered Asthma A...
# 4     [These are the new cars that depreciate least]
#
#                                             negative
# 0  [Porsche launches into second story of New Jer...
# 1  [Bode Miller delivered his twin boys after mid...
# 2  [11 reasons to watch Week 11 of the 2019 NFL s...
# 3  [Porsche launches into second story of New Jer...
# ...
